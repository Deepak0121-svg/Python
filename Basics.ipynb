# %%
print("Hello Demon")
# Out:
# Hello Demon

# %%
Reg_no=int(input("Enter your Register number"))
Reg_no
# Out:
# Enter your Register number 1018
# 1018

# %%
name=input("Enter ypur name")
Reg_no=int(input("Enter yourr Register no"))
DOB=str(input("Enter your DOB"))
print("My name is",name)
print("My Reg_no is",Reg_no)
print("My DOB is",DOB)
# Out:
# Enter ypur name DEMON
# Enter yourr Register no 1018
# Enter your DOB 18/3/2000
# My name is DEMON
# My Reg_no is 1018
# My DOB is 18/3/2000

# %%
# Basic Plot

# %%
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import matplotlib.pyplot as plt
plt.plot([2,4,6,8],[8,16,24,32])
plt.show()

# %%
plt.plot([2,4,6,8],[8,16,24,32])
plt.plot([2,4,6,8],[8,16,24,32])
plt.show()
